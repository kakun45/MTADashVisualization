# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'http://web.mta.info/developers/turnstile.html'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
#soup.findAll('a')

# %%
one_a_tag = soup.findAll('a')[36]
link = one_a_tag['href']

# %%
download_url = 'http://web.mta.info/developers/'+link
urllib.request.urlretrieve(download_url, './'+link[link.find('/turnstile_')+1:])
# Out:
# ('./turnstile_191019.txt', <http.client.HTTPMessage at 0x11dd161d0>)

# %%
time.sleep(1)

# %%
# for i in range(36,len(soup.findAll('a'))+1):
#     one_a_tag = soup.findAll('a')[i]
#     link = one_a_tag['href']
#     download_url = 'http://web.mta.info/developers/'+link
#     urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
#     time.sleep(1)

# %%
MTAdata = pd.read_csv('turnstile_191012.txt')#, header = None

# %%
MTAdata.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7224009
# 1  REGULAR  7224019
# 2  REGULAR  7224033
# 3  REGULAR  7224095
# 4  REGULAR  7224095
#
#    EXITS
# 0                                            2447060
# 1                                            2447067
# 2                                            2447074
# 3                                            2447082
# 4                                            2447082

# %%
MTAData = MTAdata.to_csv(r'MTAData.csv') #csv - coma separated values

# %%
MTAdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206859 entries, 0 to 206858
# Data columns (total 11 columns):
# C/A                                                                     206859 non-null object
# UNIT                                                                    206859 non-null object
# SCP                                                                     206859 non-null object
# STATION                                                                 206859 non-null object
# LINENAME                                                                206859 non-null object
# DIVISION                                                                206859 non-null object
# DATE                                                                    206859 non-null object
# TIME                                                                    206859 non-null object
# DESC                                                                    206859 non-null object
# ...

# %%
MTAdata.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/05/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7224009
# 1  REGULAR  7224019
# 2  REGULAR  7224033
# 3  REGULAR  7224095
# 4  REGULAR  7224095
#
#    EXITS
# 0                                            2447060
# 1                                            2447067
# 2                                            2447074
# 3                                            2447082
# 4                                            2447082

# %%
MTAdata = MTAdata.drop(['C/A','DIVISION','UNIT'],axis=1)

# %%
MTAdata.head()
# Out:
#         SCP STATION LINENAME        DATE      TIME     DESC  ENTRIES  \
# 0  02-00-00   59 ST  NQR456W  10/05/2019  00:00:00  REGULAR  7224009
# 1  02-00-00   59 ST  NQR456W  10/05/2019  04:00:00  REGULAR  7224019
# 2  02-00-00   59 ST  NQR456W  10/05/2019  08:00:00  REGULAR  7224033
# 3  02-00-00   59 ST  NQR456W  10/05/2019  12:00:00  REGULAR  7224095
# 4  02-00-00   59 ST  NQR456W  10/05/2019  16:00:00  REGULAR  7224095
#
#    EXITS
# 0                                            2447060
# 1                                            2447067
# 2                                            2447074
# 3                                            2447082
# 4                                            2447082

# %%
MTAdata.columns
# Out:
# Index(['SCP', 'STATION', 'LINENAME', 'DATE', 'TIME', 'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
extra_data = MTAdata.assign(INTHESTATION = MTAdata['ENTRIES'] - MTAdata['EXITS                                                               '])

# %%
extra_data.head()
# Out:
#         SCP STATION LINENAME        DATE      TIME     DESC  ENTRIES  \
# 0  02-00-00   59 ST  NQR456W  10/05/2019  00:00:00  REGULAR  7224009
# 1  02-00-00   59 ST  NQR456W  10/05/2019  04:00:00  REGULAR  7224019
# 2  02-00-00   59 ST  NQR456W  10/05/2019  08:00:00  REGULAR  7224033
# 3  02-00-00   59 ST  NQR456W  10/05/2019  12:00:00  REGULAR  7224095
# 4  02-00-00   59 ST  NQR456W  10/05/2019  16:00:00  REGULAR  7224095
#
#    EXITS                                                                 \
# 0                                            2447060
# 1                                            2447067
# 2                                            2447074
# 3                                            2447082
# 4                                            2447082
#
#    INTHESTATION
# 0       4776949
# 1       4776952
# 2       4776959
# 3       4777013
# 4       4777013

# %%
extra_data = extra_data.drop(['SCP','DESC'],axis=1)
extra_data.head()
# Out:
#   STATION LINENAME        DATE      TIME  ENTRIES  \
# 0   59 ST  NQR456W  10/05/2019  00:00:00  7224009
# 1   59 ST  NQR456W  10/05/2019  04:00:00  7224019
# 2   59 ST  NQR456W  10/05/2019  08:00:00  7224033
# 3   59 ST  NQR456W  10/05/2019  12:00:00  7224095
# 4   59 ST  NQR456W  10/05/2019  16:00:00  7224095
#
#    EXITS                                                                 \
# 0                                            2447060
# 1                                            2447067
# 2                                            2447074
# 3                                            2447082
# 4                                            2447082
#
#    INTHESTATION
# 0       4776949
# 1       4776952
# 2       4776959
# 3       4777013
# 4       4777013
